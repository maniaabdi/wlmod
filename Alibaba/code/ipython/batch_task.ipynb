# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('/local0/alibaba2018/batch_task.csv')

df =
# Out:
#                                          M1        1        j_1  1.1  \
# 0                                      R2_1      1.0        j_2    1
# 1                                        M1      1.0        j_2    1
# 2                                      R6_3    371.0        j_3    1
# 3                                    J4_2_3   1111.0        j_3    1
# 4                                      R2_1      1.0        j_3    1
# 5                                    J8_3_7   1111.0        j_3    1
# 6                                        M3  12846.0        j_3    1
# 7                                      R9_8      1.0        j_3    1
# 8                                      R1_3    371.0        j_3    1
# 9                                      R5_4      1.0        j_3    1
# 10                                     R7_6      1.0        j_3    1
# 11                                       M1      1.0        j_7    1
# 12                                     R2_1      1.0        j_7    1
# ...
